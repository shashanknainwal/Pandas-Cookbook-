# %%
import pandas as pd

# %%
movie= pd.read_csv("movie.csv")

# %%
movie.head()
# Out:
#    color      director_name  num_critic_for_reviews  duration  \
# 0  Color      James Cameron                   723.0     178.0
# 1  Color     Gore Verbinski                   302.0     169.0
# 2  Color         Sam Mendes                   602.0     148.0
# 3  Color  Christopher Nolan                   813.0     164.0
# 4    NaN        Doug Walker                     NaN       NaN
#
#    director_facebook_likes  actor_3_facebook_likes      actor_2_name  \
# 0                      0.0                   855.0  Joel David Moore
# 1                    563.0                  1000.0     Orlando Bloom
# 2                      0.0                   161.0      Rory Kinnear
# 3                  22000.0                 23000.0    Christian Bale
# 4                    131.0                     NaN        Rob Walker
#
#    actor_1_facebook_likes        gross                           genres  \
# 0                  1000.0  760505847.0  Action|Adventure|Fantasy|Sci-Fi
# ...

# %%
# To see the index
movie.index
# Out:
# RangeIndex(start=0, stop=4916, step=1)

# %%
# to see columns
movie.columns
# Out:
# Index(['color', 'director_name', 'num_critic_for_reviews', 'duration',
#        'director_facebook_likes', 'actor_3_facebook_likes', 'actor_2_name',
#        'actor_1_facebook_likes', 'gross', 'genres', 'actor_1_name',
#        'movie_title', 'num_voted_users', 'cast_total_facebook_likes',
#        'actor_3_name', 'facenumber_in_poster', 'plot_keywords',
#        'movie_imdb_link', 'num_user_for_reviews', 'language', 'country',
#        'content_rating', 'budget', 'title_year', 'actor_2_facebook_likes',
#        'imdb_score', 'aspect_ratio', 'movie_facebook_likes'],
#       dtype='object')

# %%
#To see values
movie.values
# Out:
# array([['Color', 'James Cameron', 723.0, ..., 7.9, 1.78, 33000],
#        ['Color', 'Gore Verbinski', 302.0, ..., 7.1, 2.35, 0],
#        ['Color', 'Sam Mendes', 602.0, ..., 6.8, 2.35, 85000],
#        ...,
#        ['Color', 'Benjamin Roberds', 13.0, ..., 6.3, nan, 16],
#        ['Color', 'Daniel Hsia', 14.0, ..., 6.3, 2.35, 660],
#        ['Color', 'Jon Gunn', 43.0, ..., 6.6, 1.85, 456]], dtype=object)

# %%
# Outputing type

# %%
type(movie.index)
# Out:
# pandas.indexes.range.RangeIndex

# %%
type(movie.columns)
# Out:
# pandas.indexes.base.Index

# %%
type(movie.values)
# Out:
# numpy.ndarray

# %%
index= movie.index

# %%
index.values
# Out:
# array([   0,    1,    2, ..., 4913, 4914, 4915])

# %%
columns= movie.columns
columns.values
# Out:
# array(['color', 'director_name', 'num_critic_for_reviews', 'duration',
#        'director_facebook_likes', 'actor_3_facebook_likes', 'actor_2_name',
#        'actor_1_facebook_likes', 'gross', 'genres', 'actor_1_name',
#        'movie_title', 'num_voted_users', 'cast_total_facebook_likes',
#        'actor_3_name', 'facenumber_in_poster', 'plot_keywords',
#        'movie_imdb_link', 'num_user_for_reviews', 'language', 'country',
#        'content_rating', 'budget', 'title_year', 'actor_2_facebook_likes',
#        'imdb_score', 'aspect_ratio', 'movie_facebook_likes'], dtype=object)

# %%
movie.dtypes
# Out:
# color                         object
# director_name                 object
# num_critic_for_reviews       float64
# duration                     float64
# director_facebook_likes      float64
# actor_3_facebook_likes       float64
# actor_2_name                  object
# actor_1_facebook_likes       float64
# gross                        float64
# genres                        object
# actor_1_name                  object
# movie_title                   object
# num_voted_users                int64
# cast_total_facebook_likes      int64
# actor_3_name                  object
# facenumber_in_poster         float64
# plot_keywords                 object
# movie_imdb_link               object
# num_user_for_reviews         float64
# language                      object
# country                       object
# content_rating                object
# budget                       float64
# title_year                   float64
# actor_2_facebook_likes       float64
# ...

# %% [markdown]
# # selecting a single column of data as a series
# 1. Index operator
# 2. dot notation

# %%
movie['director_name']
# Out:
# 0            James Cameron
# 1           Gore Verbinski
# 2               Sam Mendes
# 3        Christopher Nolan
# 4              Doug Walker
# 5           Andrew Stanton
# 6                Sam Raimi
# 7             Nathan Greno
# 8              Joss Whedon
# 9              David Yates
# 10             Zack Snyder
# 11            Bryan Singer
# 12            Marc Forster
# 13          Gore Verbinski
# 14          Gore Verbinski
# 15             Zack Snyder
# 16          Andrew Adamson
# 17             Joss Whedon
# 18            Rob Marshall
# 19        Barry Sonnenfeld
# 20           Peter Jackson
# 21               Marc Webb
# 22            Ridley Scott
# 23           Peter Jackson
# 24             Chris Weitz
# 25           Peter Jackson
# 26           James Cameron
# 27           Anthony Russo
# 28              Peter Berg
# 29         Colin Trevorrow
#                ...
# 4886            Eric Eason
# 4887              Uwe Boll
# 4888     Richard Linklater
# ...

# %%
movie.director_name
# Out:
# 0            James Cameron
# 1           Gore Verbinski
# 2               Sam Mendes
# 3        Christopher Nolan
# 4              Doug Walker
# 5           Andrew Stanton
# 6                Sam Raimi
# 7             Nathan Greno
# 8              Joss Whedon
# 9              David Yates
# 10             Zack Snyder
# 11            Bryan Singer
# 12            Marc Forster
# 13          Gore Verbinski
# 14          Gore Verbinski
# 15             Zack Snyder
# 16          Andrew Adamson
# 17             Joss Whedon
# 18            Rob Marshall
# 19        Barry Sonnenfeld
# 20           Peter Jackson
# 21               Marc Webb
# 22            Ridley Scott
# 23           Peter Jackson
# 24             Chris Weitz
# 25           Peter Jackson
# 26           James Cameron
# 27           Anthony Russo
# 28              Peter Berg
# 29         Colin Trevorrow
#                ...
# 4886            Eric Eason
# 4887              Uwe Boll
# 4888     Richard Linklater
# ...

# %%
# converting series back to DF
director=movie['director_name']

# %%
director.to_frame()
# Out:
#            director_name
# 0          James Cameron
# 1         Gore Verbinski
# 2             Sam Mendes
# 3      Christopher Nolan
# 4            Doug Walker
# 5         Andrew Stanton
# 6              Sam Raimi
# 7           Nathan Greno
# 8            Joss Whedon
# 9            David Yates
# 10           Zack Snyder
# 11          Bryan Singer
# 12          Marc Forster
# 13        Gore Verbinski
# 14        Gore Verbinski
# 15           Zack Snyder
# 16        Andrew Adamson
# 17           Joss Whedon
# 18          Rob Marshall
# 19      Barry Sonnenfeld
# 20         Peter Jackson
# 21             Marc Webb
# 22          Ridley Scott
# 23         Peter Jackson
# 24           Chris Weitz
# 25         Peter Jackson
# 26         James Cameron
# 27         Anthony Russo
# 28            Peter Berg
# 29       Colin Trevorrow
# ...                  ...
# 4886          Eric Eason
# 4887            Uwe Boll
# 4888   Richard Linklater
# 4889     Joseph Mazzella
# 4890        Travis Legge
# ...

# %% [markdown]
# ## Operations on Series

# %%
# Value_counts

# %%
director=movie['director_name']
director.value_counts()
# Out:
# Steven Spielberg        26
# Woody Allen             22
# Martin Scorsese         20
# Clint Eastwood          20
# Spike Lee               16
# Ridley Scott            16
# Steven Soderbergh       15
# Renny Harlin            15
# Tim Burton              14
# Oliver Stone            14
# Ron Howard              13
# Robert Rodriguez        13
# Barry Levinson          13
# Robert Zemeckis         13
# Joel Schumacher         13
# Kevin Smith             12
# Tony Scott              12
# Michael Bay             12
# Brian De Palma          12
# Chris Columbus          11
# Rob Reiner              11
# Richard Donner          11
# Shawn Levy              11
# Francis Ford Coppola    11
# Sam Raimi               11
# Richard Linklater       11
# Paul W.S. Anderson      10
# John Carpenter          10
# Bobby Farrelly          10
# Stephen Frears          10
#                         ..
# Guillaume Ivernel        1
# Gregory Nava             1
# Mike Gabriel             1
# ...

# %%
# Shape

# %%
director.shape
# Out:
# (4916,)

# %%
# Size

# %%
director.size
# Out:
# 4916

# %%
#Length

# %%
len(director)
# Out:
# 4916

# %%
#Count- Returns non missing values

# %%
director.count()
# Out:
# 4814

# %%
# Series min, max, mediaan, std

# %%
director.min
# Out:
# <bound method Series.min of 0            James Cameron
# 1           Gore Verbinski
# 2               Sam Mendes
# 3        Christopher Nolan
# 4              Doug Walker
# 5           Andrew Stanton
# 6                Sam Raimi
# 7             Nathan Greno
# 8              Joss Whedon
# 9              David Yates
# 10             Zack Snyder
# 11            Bryan Singer
# 12            Marc Forster
# 13          Gore Verbinski
# 14          Gore Verbinski
# 15             Zack Snyder
# 16          Andrew Adamson
# 17             Joss Whedon
# 18            Rob Marshall
# 19        Barry Sonnenfeld
# 20           Peter Jackson
# 21               Marc Webb
# 22            Ridley Scott
# 23           Peter Jackson
# 24             Chris Weitz
# 25           Peter Jackson
# 26           James Cameron
# 27           Anthony Russo
# 28              Peter Berg
# 29         Colin Trevorrow
#                ...
# 4886            Eric Eason
# 4887              Uwe Boll
# ...

# %%
director.max
# Out:
# <bound method Series.max of 0            James Cameron
# 1           Gore Verbinski
# 2               Sam Mendes
# 3        Christopher Nolan
# 4              Doug Walker
# 5           Andrew Stanton
# 6                Sam Raimi
# 7             Nathan Greno
# 8              Joss Whedon
# 9              David Yates
# 10             Zack Snyder
# 11            Bryan Singer
# 12            Marc Forster
# 13          Gore Verbinski
# 14          Gore Verbinski
# 15             Zack Snyder
# 16          Andrew Adamson
# 17             Joss Whedon
# 18            Rob Marshall
# 19        Barry Sonnenfeld
# 20           Peter Jackson
# 21               Marc Webb
# 22            Ridley Scott
# 23           Peter Jackson
# 24             Chris Weitz
# 25           Peter Jackson
# 26           James Cameron
# 27           Anthony Russo
# 28              Peter Berg
# 29         Colin Trevorrow
#                ...
# 4886            Eric Eason
# 4887              Uwe Boll
# ...

# %%
director.describe()
# Out:
# count                 4814
# unique                2397
# top       Steven Spielberg
# freq                    26
# Name: director_name, dtype: object

# %%
# count is null

# %%
director.isnull()
# Out:
# 0       False
# 1       False
# 2       False
# 3       False
# 4       False
# 5       False
# 6       False
# 7       False
# 8       False
# 9       False
# 10      False
# 11      False
# 12      False
# 13      False
# 14      False
# 15      False
# 16      False
# 17      False
# 18      False
# 19      False
# 20      False
# 21      False
# 22      False
# 23      False
# 24      False
# 25      False
# 26      False
# 27      False
# 28      False
# 29      False
#         ...
# 4886    False
# 4887    False
# 4888    False
# 4889    False
# 4890    False
# 4891    False
# 4892    False
# 4893    False
# 4894    False
# 4895    False
# 4896    False
# 4897    False
# 4898    False
# 4899    False
# 4900    False
# 4901    False
# 4902    False
# 4903    False
# 4904    False
# 4905    False
# 4906    False
# 4907    False
# 4908    False
# 4909    False
# 4910    False
# 4911    False
# 4912     True
# 4913    False
# 4914    False
# 4915    False
# ...

# %%
director_isfilled_na= director.fillna(0)

# %%
director_isfilled_na
# Out:
# 0            James Cameron
# 1           Gore Verbinski
# 2               Sam Mendes
# 3        Christopher Nolan
# 4              Doug Walker
# 5           Andrew Stanton
# 6                Sam Raimi
# 7             Nathan Greno
# 8              Joss Whedon
# 9              David Yates
# 10             Zack Snyder
# 11            Bryan Singer
# 12            Marc Forster
# 13          Gore Verbinski
# 14          Gore Verbinski
# 15             Zack Snyder
# 16          Andrew Adamson
# 17             Joss Whedon
# 18            Rob Marshall
# 19        Barry Sonnenfeld
# 20           Peter Jackson
# 21               Marc Webb
# 22            Ridley Scott
# 23           Peter Jackson
# 24             Chris Weitz
# 25           Peter Jackson
# 26           James Cameron
# 27           Anthony Russo
# 28              Peter Berg
# 29         Colin Trevorrow
#                ...
# 4886            Eric Eason
# 4887              Uwe Boll
# 4888     Richard Linklater
# ...

# %%
director_drop_na= director.dropna()
director_drop_na
# Out:
# 0            James Cameron
# 1           Gore Verbinski
# 2               Sam Mendes
# 3        Christopher Nolan
# 4              Doug Walker
# 5           Andrew Stanton
# 6                Sam Raimi
# 7             Nathan Greno
# 8              Joss Whedon
# 9              David Yates
# 10             Zack Snyder
# 11            Bryan Singer
# 12            Marc Forster
# 13          Gore Verbinski
# 14          Gore Verbinski
# 15             Zack Snyder
# 16          Andrew Adamson
# 17             Joss Whedon
# 18            Rob Marshall
# 19        Barry Sonnenfeld
# 20           Peter Jackson
# 21               Marc Webb
# 22            Ridley Scott
# 23           Peter Jackson
# 24             Chris Weitz
# 25           Peter Jackson
# 26           James Cameron
# 27           Anthony Russo
# 28              Peter Berg
# 29         Colin Trevorrow
#                ...
# 4885           Neil LaBute
# 4886            Eric Eason
# 4887              Uwe Boll
# ...

# %%
# To find if there are Nan

# %%
director.hasnans
# Out:
# True

# %% [markdown]
# ## Pandas Chaining

# %%
director.value_counts().head()
# Out:
# Steven Spielberg    26
# Woody Allen         22
# Martin Scorsese     20
# Clint Eastwood      20
# Spike Lee           16
# Name: director_name, dtype: int64

# %%
# count the number of missing values, applicable to both series and dataframa

# %%
director.isnull().sum()
# Out:
# 102

# %%
# converting NaN to 0(integer)

# %%
director.fillna(0).astype(str).head()
# Out:
# 0        James Cameron
# 1       Gore Verbinski
# 2           Sam Mendes
# 3    Christopher Nolan
# 4          Doug Walker
# Name: director_name, dtype: object

# %%
# Meaningful Index using set_index

# %%
movie.head()
# Out:
#    color      director_name  num_critic_for_reviews  duration  \
# 0  Color      James Cameron                   723.0     178.0
# 1  Color     Gore Verbinski                   302.0     169.0
# 2  Color         Sam Mendes                   602.0     148.0
# 3  Color  Christopher Nolan                   813.0     164.0
# 4    NaN        Doug Walker                     NaN       NaN
#
#    director_facebook_likes  actor_3_facebook_likes      actor_2_name  \
# 0                      0.0                   855.0  Joel David Moore
# 1                    563.0                  1000.0     Orlando Bloom
# 2                      0.0                   161.0      Rory Kinnear
# 3                  22000.0                 23000.0    Christian Bale
# 4                    131.0                     NaN        Rob Walker
#
#    actor_1_facebook_likes        gross                           genres  \
# 0                  1000.0  760505847.0  Action|Adventure|Fantasy|Sci-Fi
# ...

# %%
movie.set_index('movie_title')
# Out:
#                                                        color  \
# movie_title
# Avatar                                                 Color
# Pirates of the Caribbean: At World's End               Color
# Spectre                                                Color
# The Dark Knight Rises                                  Color
# Star Wars: Episode VII - The Force Awakens               NaN
# John Carter                                            Color
# Spider-Man 3                                           Color
# Tangled                                                Color
# Avengers: Age of Ultron                                Color
# Harry Potter and the Half-Blood Prince                 Color
# Batman v Superman: Dawn of Justice                     Color
# Superman Returns                                       Color
# Quantum of Solace                                      Color
# Pirates of the Caribbean: Dead Man's Chest             Color
# ...

# %%
movie= pd.read_csv("movie.csv",index_col="movie_title")

# %%
movie
# Out:
#                                                        color  \
# movie_title
# Avatar                                                 Color
# Pirates of the Caribbean: At World's End               Color
# Spectre                                                Color
# The Dark Knight Rises                                  Color
# Star Wars: Episode VII - The Force Awakens               NaN
# John Carter                                            Color
# Spider-Man 3                                           Color
# Tangled                                                Color
# Avengers: Age of Ultron                                Color
# Harry Potter and the Half-Blood Prince                 Color
# Batman v Superman: Dawn of Justice                     Color
# Superman Returns                                       Color
# Quantum of Solace                                      Color
# Pirates of the Caribbean: Dead Man's Chest             Color
# ...

# %%
#reset index- This puts the range index back again

# %%
movie.reset_index()
# Out:
#                                       movie_title            color  \
# 0                                          Avatar            Color
# 1        Pirates of the Caribbean: At World's End            Color
# 2                                         Spectre            Color
# 3                           The Dark Knight Rises            Color
# 4      Star Wars: Episode VII - The Force Awakens              NaN
# 5                                     John Carter            Color
# 6                                    Spider-Man 3            Color
# 7                                         Tangled            Color
# 8                         Avengers: Age of Ultron            Color
# 9          Harry Potter and the Half-Blood Prince            Color
# 10             Batman v Superman: Dawn of Justice            Color
# 11                               Superman Returns            Color
# 12                              Quantum of Solace            Color
# ...

# %%
# Renaming rows and column names

# %% [markdown]
# 1. read the csv
# 2. creat a dictionary - old and new value as key value
# 3. df.rename(index=idx_rename, columns= col_rename)
# In this case, we are renaming index values

# %%
movie.head(3)
# Out:
#                                           color   director_name  \
# movie_title
# Avatar                                    Color   James Cameron
# Pirates of the Caribbean: At World's End  Color  Gore Verbinski
# Spectre                                   Color      Sam Mendes
#
#                                           num_critic_for_reviews  duration  \
# movie_title
# Avatar                                                     723.0     178.0
# Pirates of the Caribbean: At World's End                   302.0     169.0
# Spectre                                                    602.0     148.0
#
#                                           director_facebook_likes  \
# movie_title
# Avatar                                                        0.0
# Pirates of the Caribbean: At World's End                    563.0
# Spectre                                                       0.0
#
#                                           actor_3_facebook_likes  \
# movie_title
# ...

# %%
director_new_name ={"director_name":"director"}
index_new_name={"Avatar":"Avatar1"}

# %%
movie.rename(index= index_new_name, columns=director_new_name)
# Out:
#                                                        color  \
# movie_title
# Avatar1                                                Color
# Pirates of the Caribbean: At World's End               Color
# Spectre                                                Color
# The Dark Knight Rises                                  Color
# Star Wars: Episode VII - The Force Awakens               NaN
# John Carter                                            Color
# Spider-Man 3                                           Color
# Tangled                                                Color
# Avengers: Age of Ultron                                Color
# Harry Potter and the Half-Blood Prince                 Color
# Batman v Superman: Dawn of Justice                     Color
# Superman Returns                                       Color
# Quantum of Solace                                      Color
# Pirates of the Caribbean: Dead Man's Chest             Color
# ...

# %%
# Renaming multiple columns

# %%
director_new_name ={"num_critic_for_reviews":"critic"}
movie_new_name={"duration":"time"}

# %%
movie.rename( columns={"num_critic_for_reviews":"critic","duration":"time"})
# Out:
#                                                        color  \
# movie_title
# Avatar                                                 Color
# Pirates of the Caribbean: At World's End               Color
# Spectre                                                Color
# The Dark Knight Rises                                  Color
# Star Wars: Episode VII - The Force Awakens               NaN
# John Carter                                            Color
# Spider-Man 3                                           Color
# Tangled                                                Color
# Avengers: Age of Ultron                                Color
# Harry Potter and the Half-Blood Prince                 Color
# Batman v Superman: Dawn of Justice                     Color
# Superman Returns                                       Color
# Quantum of Solace                                      Color
# Pirates of the Caribbean: Dead Man's Chest             Color
# ...

# %%
#Rename Movie Index
movie.index.names=['Movie']
#df.rename(index={0:'Date'}
#df.index.names = ['Date']

# %%
movie
# Out:
#                                                        color  \
# Movie
# Avatar                                                 Color
# Pirates of the Caribbean: At World's End               Color
# Spectre                                                Color
# The Dark Knight Rises                                  Color
# Star Wars: Episode VII - The Force Awakens               NaN
# John Carter                                            Color
# Spider-Man 3                                           Color
# Tangled                                                Color
# Avengers: Age of Ultron                                Color
# Harry Potter and the Half-Blood Prince                 Color
# Batman v Superman: Dawn of Justice                     Color
# Superman Returns                                       Color
# Quantum of Solace                                      Color
# Pirates of the Caribbean: Dead Man's Chest             Color
# ...

# %%
del movie["color"]

# %%
movie
# Out:
#                                                   director_name  \
# Movie
# Avatar                                            James Cameron
# Pirates of the Caribbean: At World's End         Gore Verbinski
# Spectre                                              Sam Mendes
# The Dark Knight Rises                         Christopher Nolan
# Star Wars: Episode VII - The Force Awakens          Doug Walker
# John Carter                                      Andrew Stanton
# Spider-Man 3                                          Sam Raimi
# Tangled                                            Nathan Greno
# Avengers: Age of Ultron                             Joss Whedon
# Harry Potter and the Half-Blood Prince              David Yates
# Batman v Superman: Dawn of Justice                  Zack Snyder
# Superman Returns                                   Bryan Singer
# Quantum of Solace                                  Marc Forster
# ...

# %% [markdown]
# # Essential Dataframe operations

# %%
# Selecting multiple dataframe columns

# %%
movie
# Out:
#                                                   director_name  \
# Movie
# Avatar                                            James Cameron
# Pirates of the Caribbean: At World's End         Gore Verbinski
# Spectre                                              Sam Mendes
# The Dark Knight Rises                         Christopher Nolan
# Star Wars: Episode VII - The Force Awakens          Doug Walker
# John Carter                                      Andrew Stanton
# Spider-Man 3                                          Sam Raimi
# Tangled                                            Nathan Greno
# Avengers: Age of Ultron                             Joss Whedon
# Harry Potter and the Half-Blood Prince              David Yates
# Batman v Superman: Dawn of Justice                  Zack Snyder
# Superman Returns                                   Bryan Singer
# Quantum of Solace                                  Marc Forster
# ...

# %%
columns=['director_name', 'num_critic_for_reviews', 'duration',
       'director_facebook_likes', 'actor_3_facebook_likes']

# %%
movie[columns]
# Out:
#                                                   director_name  \
# Movie
# Avatar                                            James Cameron
# Pirates of the Caribbean: At World's End         Gore Verbinski
# Spectre                                              Sam Mendes
# The Dark Knight Rises                         Christopher Nolan
# Star Wars: Episode VII - The Force Awakens          Doug Walker
# John Carter                                      Andrew Stanton
# Spider-Man 3                                          Sam Raimi
# Tangled                                            Nathan Greno
# Avengers: Age of Ultron                             Joss Whedon
# Harry Potter and the Half-Blood Prince              David Yates
# Batman v Superman: Dawn of Justice                  Zack Snyder
# Superman Returns                                   Bryan Singer
# Quantum of Solace                                  Marc Forster
# ...

# %%
# Missing values

# %%
movie.isnull().sum()
# Out:
# director_name                102
# num_critic_for_reviews        49
# duration                      15
# director_facebook_likes      102
# actor_3_facebook_likes        23
# actor_2_name                  13
# actor_1_facebook_likes         7
# gross                        862
# genres                         0
# actor_1_name                   7
# num_voted_users                0
# cast_total_facebook_likes      0
# actor_3_name                  23
# facenumber_in_poster          13
# plot_keywords                152
# movie_imdb_link                0
# num_user_for_reviews          21
# language                      12
# country                        5
# content_rating               300
# budget                       484
# title_year                   106
# actor_2_facebook_likes        13
# imdb_score                     0
# aspect_ratio                 326
# movie_facebook_likes           0
# dtype: int64

# %%
movie.isnull().sum().sum()
# Out:
# 2635

# %%
# To find missing values in a DataFrame

# %%
movie.isnull().any().any()
# Out:
# True

# %%
# Get data type counts

# %%
    movie.isnull().get_dtype_counts()
# Out:
# bool    26
# dtype: int64

# %%
college= pd.read_csv("college.csv",index_col="INSTNM")

# %%
college.head()
# Out:
#                                            CITY STABBR  HBCU  MENONLY  \
# INSTNM
# Alabama A & M University                 Normal     AL   1.0      0.0
# University of Alabama at Birmingham  Birmingham     AL   0.0      0.0
# Amridge University                   Montgomery     AL   0.0      0.0
# University of Alabama in Huntsville  Huntsville     AL   0.0      0.0
# Alabama State University             Montgomery     AL   1.0      0.0
#
#                                      WOMENONLY  RELAFFIL  SATVRMID  SATMTMID  \
# INSTNM
# Alabama A & M University                   0.0         0     424.0     420.0
# University of Alabama at Birmingham        0.0         0     570.0     565.0
# Amridge University                         0.0         1       NaN       NaN
# University of Alabama in Huntsville        0.0         0     595.0     590.0
# Alabama State University                   0.0         0     425.0     430.0
#
#                                      DISTANCEONLY     UGDS  \
# ...

# %%
college_ugds= college.filter(like='UGDS_')

# %%
college_ugds.head()
# Out:
#                                      UGDS_WHITE  UGDS_BLACK  UGDS_HISP  \
# INSTNM
# Alabama A & M University                 0.0333      0.9353     0.0055
# University of Alabama at Birmingham      0.5922      0.2600     0.0283
# Amridge University                       0.2990      0.4192     0.0069
# University of Alabama in Huntsville      0.6988      0.1255     0.0382
# Alabama State University                 0.0158      0.9208     0.0121
#
#                                      UGDS_ASIAN  UGDS_AIAN  UGDS_NHPI  \
# INSTNM
# Alabama A & M University                 0.0019     0.0024     0.0019
# University of Alabama at Birmingham      0.0518     0.0022     0.0007
# Amridge University                       0.0034     0.0000     0.0000
# University of Alabama in Huntsville      0.0376     0.0143     0.0002
# Alabama State University                 0.0019     0.0010     0.0006
#
#                                      UGDS_2MOR  UGDS_NRA  UGDS_UNKN
# INSTNM
# ...

# %%
college_ugds.count()
# Out:
# UGDS_WHITE    6874
# UGDS_BLACK    6874
# UGDS_HISP     6874
# UGDS_ASIAN    6874
# UGDS_AIAN     6874
# UGDS_NHPI     6874
# UGDS_2MOR     6874
# UGDS_NRA      6874
# UGDS_UNKN     6874
# dtype: int64

# %%
college_ugds.sum()
# by default is axis =0
# Out:
# UGDS_WHITE    3507.1643
# UGDS_BLACK    1306.0369
# UGDS_HISP     1111.0782
# UGDS_ASIAN     230.5831
# UGDS_AIAN       94.9476
# UGDS_NHPI       31.4066
# UGDS_2MOR      164.6344
# UGDS_NRA       110.5739
# UGDS_UNKN      310.5772
# dtype: float64

# %%
college_ugds.sum(axis=1)
# Out:
# INSTNM
# Alabama A & M University                                  1.0000
# University of Alabama at Birmingham                       0.9999
# Amridge University                                        1.0000
# University of Alabama in Huntsville                       1.0000
# Alabama State University                                  1.0000
# The University of Alabama                                 1.0000
# Central Alabama Community College                         1.0000
# Athens State University                                   0.9999
# Auburn University at Montgomery                           0.9999
# Auburn University                                         1.0000
# Birmingham Southern College                               1.0001
# Chattahoochee Valley Community College                    1.0000
# Concordia College Alabama                                 1.0001
# South University-Montgomery                               1.0000
# ...

# %%
# To get the distribution of each column

# %%
college_ugds.median(axis='index')
#college_ugds.median(axis=0)
# Out:
# UGDS_WHITE    0.55570
# UGDS_BLACK    0.10005
# UGDS_HISP     0.07140
# UGDS_ASIAN    0.01290
# UGDS_AIAN     0.00260
# UGDS_NHPI     0.00000
# UGDS_2MOR     0.01750
# UGDS_NRA      0.00000
# UGDS_UNKN     0.01430
# dtype: float64

# %% [markdown]
# ** remember
#
# axis= 0, meaning i want you to move down and move across the row axis. The operation happens down

# %%
# Cumsum to caputure percentage values

# %%
college_ugds.cumsum(axis=1)
# Out:
#                                                     UGDS_WHITE  UGDS_BLACK  \
# INSTNM
# Alabama A & M University                                0.0333      0.9686
# University of Alabama at Birmingham                     0.5922      0.8522
# Amridge University                                      0.2990      0.7182
# University of Alabama in Huntsville                     0.6988      0.8243
# Alabama State University                                0.0158      0.9366
# The University of Alabama                               0.7825      0.8944
# Central Alabama Community College                       0.7255      0.9868
# Athens State University                                 0.7823      0.9023
# Auburn University at Montgomery                         0.5328      0.8704
# Auburn University                                       0.8507      0.9211
# Birmingham Southern College                             0.7983      0.9085
# ...
