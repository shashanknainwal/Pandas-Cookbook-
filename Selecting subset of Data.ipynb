# %% [markdown]
# ** .loc- works with index location
#    .iloc- works with integer location

# %%
import pandas as pd

# %%
college= pd.read_csv("college.csv",index_col='INSTNM')

# %%
college.head()
# Out:
#                                            CITY STABBR  HBCU  MENONLY  \
# INSTNM
# Alabama A & M University                 Normal     AL   1.0      0.0
# University of Alabama at Birmingham  Birmingham     AL   0.0      0.0
# Amridge University                   Montgomery     AL   0.0      0.0
# University of Alabama in Huntsville  Huntsville     AL   0.0      0.0
# Alabama State University             Montgomery     AL   1.0      0.0
#
#                                      WOMENONLY  RELAFFIL  SATVRMID  SATMTMID  \
# INSTNM
# Alabama A & M University                   0.0         0     424.0     420.0
# University of Alabama at Birmingham        0.0         0     570.0     565.0
# Amridge University                         0.0         1       NaN       NaN
# University of Alabama in Huntsville        0.0         0     595.0     590.0
# Alabama State University                   0.0         0     425.0     430.0
#
#                                      DISTANCEONLY     UGDS  \
# ...

# %%
college.iloc[2]
# Out:
# CITY                  Montgomery
# STABBR                        AL
# HBCU                           0
# MENONLY                        0
# WOMENONLY                      0
# RELAFFIL                       1
# SATVRMID                     NaN
# SATMTMID                     NaN
# DISTANCEONLY                   1
# UGDS                         291
# UGDS_WHITE                 0.299
# UGDS_BLACK                0.4192
# UGDS_HISP                 0.0069
# UGDS_ASIAN                0.0034
# UGDS_AIAN                      0
# UGDS_NHPI                      0
# UGDS_2MOR                      0
# UGDS_NRA                       0
# UGDS_UNKN                 0.2715
# PPTUG_EF                  0.4536
# CURROPER                       1
# PCTPELL                   0.6801
# PCTFLOAN                  0.7795
# UG25ABV                    0.854
# MD_EARN_WNE_P10            40100
# GRAD_DEBT_MDN_SUPP         23370
# Name: Amridge University, dtype: object

# %%
college.loc['Amridge University']
# Out:
# CITY                  Montgomery
# STABBR                        AL
# HBCU                           0
# MENONLY                        0
# WOMENONLY                      0
# RELAFFIL                       1
# SATVRMID                     NaN
# SATMTMID                     NaN
# DISTANCEONLY                   1
# UGDS                         291
# UGDS_WHITE                 0.299
# UGDS_BLACK                0.4192
# UGDS_HISP                 0.0069
# UGDS_ASIAN                0.0034
# UGDS_AIAN                      0
# UGDS_NHPI                      0
# UGDS_2MOR                      0
# UGDS_NRA                       0
# UGDS_UNKN                 0.2715
# PPTUG_EF                  0.4536
# CURROPER                       1
# PCTPELL                   0.6801
# PCTFLOAN                  0.7795
# UG25ABV                    0.854
# MD_EARN_WNE_P10            40100
# GRAD_DEBT_MDN_SUPP         23370
# Name: Amridge University, dtype: object

# %%
college.iloc[2:5,1:2]
# Out:
#                                     STABBR
# INSTNM
# Amridge University                      AL
# University of Alabama in Huntsville     AL
# Alabama State University                AL

# %%
college.iloc[[1,2,5]]
# Out:
#                                            CITY STABBR  HBCU  MENONLY  \
# INSTNM
# University of Alabama at Birmingham  Birmingham     AL   0.0      0.0
# Amridge University                   Montgomery     AL   0.0      0.0
# The University of Alabama            Tuscaloosa     AL   0.0      0.0
#
#                                      WOMENONLY  RELAFFIL  SATVRMID  SATMTMID  \
# INSTNM
# University of Alabama at Birmingham        0.0         0     570.0     565.0
# Amridge University                         0.0         1       NaN       NaN
# The University of Alabama                  0.0         0     555.0     565.0
#
#                                      DISTANCEONLY     UGDS  \
# INSTNM
# University of Alabama at Birmingham           0.0  11383.0
# Amridge University                            1.0    291.0
# The University of Alabama                     0.0  29851.0
#
#                                             ...          UGDS_2MOR  UGDS_NRA  \
# ...

# %%
college.iloc[[2]]
# Out:
#                           CITY STABBR  HBCU  MENONLY  WOMENONLY  RELAFFIL  \
# INSTNM
# Amridge University  Montgomery     AL   0.0      0.0        0.0         1
#
#                     SATVRMID  SATMTMID  DISTANCEONLY   UGDS  \
# INSTNM
# Amridge University       NaN       NaN           1.0  291.0
#
#                            ...          UGDS_2MOR  UGDS_NRA  UGDS_UNKN  \
# INSTNM                     ...
# Amridge University         ...                0.0       0.0     0.2715
#
#                     PPTUG_EF  CURROPER  PCTPELL  PCTFLOAN  UG25ABV  \
# INSTNM
# Amridge University    0.4536         1   0.6801    0.7795    0.854
#
#                     MD_EARN_WNE_P10  GRAD_DEBT_MDN_SUPP
# INSTNM
# Amridge University            40100               23370
#
# [1 rows x 26 columns]

# %%
## Selecting both rows and columns from a DF in pandas

# %%
college.iloc[:1,3:]
# Out:
#                           MENONLY  WOMENONLY  RELAFFIL  SATVRMID  SATMTMID  \
# INSTNM
# Alabama A & M University      0.0        0.0         0     424.0     420.0
#
#                           DISTANCEONLY    UGDS  UGDS_WHITE  UGDS_BLACK  \
# INSTNM
# Alabama A & M University           0.0  4206.0      0.0333      0.9353
#
#                           UGDS_HISP         ...          UGDS_2MOR  UGDS_NRA  \
# INSTNM                                      ...
# Alabama A & M University     0.0055         ...                0.0    0.0059
#
#                           UGDS_UNKN  PPTUG_EF  CURROPER  PCTPELL  PCTFLOAN  \
# INSTNM
# Alabama A & M University     0.0138    0.0656         1   0.7356    0.8284
#
#                           UG25ABV  MD_EARN_WNE_P10  GRAD_DEBT_MDN_SUPP
# INSTNM
# Alabama A & M University   0.1049            30300               33888
#
# [1 rows x 23 columns]

# %%
columns=['CITY', 'STABBR', 'HBCU', 'MENONLY', 'WOMENONLY', 'RELAFFIL',
       'SATVRMID', 'SATMTMID']

# %%
rows=['Alabama A & M University', 'University of Alabama at Birmingham',
       'Amridge University', 'University of Alabama in Huntsville']

# %%
college.loc[rows,columns]
# Out:
#                                            CITY STABBR  HBCU  MENONLY  \
# INSTNM
# Alabama A & M University                 Normal     AL   1.0      0.0
# University of Alabama at Birmingham  Birmingham     AL   0.0      0.0
# Amridge University                   Montgomery     AL   0.0      0.0
# University of Alabama in Huntsville  Huntsville     AL   0.0      0.0
#
#                                      WOMENONLY  RELAFFIL  SATVRMID  SATMTMID
# INSTNM
# Alabama A & M University                   0.0         0     424.0     420.0
# University of Alabama at Birmingham        0.0         0     570.0     565.0
# Amridge University                         0.0         1       NaN       NaN
# University of Alabama in Huntsville        0.0         0     595.0     590.0

# %%
college.iloc[:10] 
# is same as college.iloc[:10,:]
# Out:
#                                                CITY STABBR  HBCU  MENONLY  \
# INSTNM
# Alabama A & M University                     Normal     AL   1.0      0.0
# University of Alabama at Birmingham      Birmingham     AL   0.0      0.0
# Amridge University                       Montgomery     AL   0.0      0.0
# University of Alabama in Huntsville      Huntsville     AL   0.0      0.0
# Alabama State University                 Montgomery     AL   1.0      0.0
# The University of Alabama                Tuscaloosa     AL   0.0      0.0
# Central Alabama Community College    Alexander City     AL   0.0      0.0
# Athens State University                      Athens     AL   0.0      0.0
# Auburn University at Montgomery          Montgomery     AL   0.0      0.0
# Auburn University                            Auburn     AL   0.0      0.0
#
#                                      WOMENONLY  RELAFFIL  SATVRMID  SATMTMID  \
# INSTNM
# ...

# %%
# Using both index labels and column names

# %%
start_index=college.index[5]
finish_index= college.index[11]

# %%
college.loc[start_index:finish_index,['WOMENONLY','SATMTMID']]
# Out:
#                                         WOMENONLY  SATMTMID
# INSTNM
# The University of Alabama                     0.0     565.0
# Central Alabama Community College             0.0       NaN
# Athens State University                       0.0       NaN
# Auburn University at Montgomery               0.0     509.0
# Auburn University                             0.0     588.0
# Birmingham Southern College                   0.0     560.0
# Chattahoochee Valley Community College        0.0       NaN

# %%
college[['WOMENONLY','SATMTMID']]
# Out:
#                                                     WOMENONLY  SATMTMID
# INSTNM
# Alabama A & M University                                  0.0     420.0
# University of Alabama at Birmingham                       0.0     565.0
# Amridge University                                        0.0       NaN
# University of Alabama in Huntsville                       0.0     590.0
# Alabama State University                                  0.0     430.0
# The University of Alabama                                 0.0     565.0
# Central Alabama Community College                         0.0       NaN
# Athens State University                                   0.0       NaN
# Auburn University at Montgomery                           0.0     509.0
# Auburn University                                         0.0     588.0
# Birmingham Southern College                               0.0     560.0
# Chattahoochee Valley Community College                    0.0       NaN
# ...

# %%
college.loc[:'University of Alabama at Birmingham',:]
# Out:
#                                            CITY STABBR  HBCU  MENONLY  \
# INSTNM
# Alabama A & M University                 Normal     AL   1.0      0.0
# University of Alabama at Birmingham  Birmingham     AL   0.0      0.0
#
#                                      WOMENONLY  RELAFFIL  SATVRMID  SATMTMID  \
# INSTNM
# Alabama A & M University                   0.0         0     424.0     420.0
# University of Alabama at Birmingham        0.0         0     570.0     565.0
#
#                                      DISTANCEONLY     UGDS  \
# INSTNM
# Alabama A & M University                      0.0   4206.0
# University of Alabama at Birmingham           0.0  11383.0
#
#                                             ...          UGDS_2MOR  UGDS_NRA  \
# INSTNM                                      ...
# Alabama A & M University                    ...             0.0000    0.0059
# University of Alabama at Birmingham         ...             0.0368    0.0179
#
# ...
